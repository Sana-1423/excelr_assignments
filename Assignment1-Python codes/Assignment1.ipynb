# %% [markdown]
# # Exercise-1(prime numbers)

# %% [markdown]
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
x=int(input())
if x>1:
    for i in range(2,int(x**0.5)+1):
        if x%i==0:
            print("not a prime")
            break
    else:
        print("prime number")
else:
    print("not a prime number")
# Out:
# 4
# not a prime

# %% [markdown]
# # Exercise-2 (Product of Random Numbers)

# %% [markdown]
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
a = random.randint(1, 100)
b = random.randint(1, 100)
print(a,b)
print(f"What is the product of {a} *{b}?")
x=int(input())
c=a*b;
if c==x:
    print( "YOU ARE CORRECT")
else:
    print("Correct ans is:",c)
    print("Better Luck next time, you need to improve")
# Out:
# 38 38
# What is the product of 38 *38?
# 10987
# Correct ans is: 1444
# Better Luck next time, you need to improve

# %% [markdown]
# # Exercise-3(Squares of Even/Odd Numbers)

# %% [markdown]
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
#SQUARE OF EVEN NUMBERS
for i in range(100,201):
    if i%2==0:
        print(f"{i}^2 = {i*i}")
# Out:
# 100^2 = 10000
# 102^2 = 10404
# 104^2 = 10816
# 106^2 = 11236
# 108^2 = 11664
# 110^2 = 12100
# 112^2 = 12544
# 114^2 = 12996
# 116^2 = 13456
# 118^2 = 13924
# 120^2 = 14400
# 122^2 = 14884
# 124^2 = 15376
# 126^2 = 15876
# 128^2 = 16384
# 130^2 = 16900
# 132^2 = 17424
# 134^2 = 17956
# 136^2 = 18496
# 138^2 = 19044
# 140^2 = 19600
# 142^2 = 20164
# 144^2 = 20736
# 146^2 = 21316
# 148^2 = 21904
# 150^2 = 22500
# 152^2 = 23104
# 154^2 = 23716
# 156^2 = 24336
# 158^2 = 24964
# 160^2 = 25600
# 162^2 = 26244
# 164^2 = 26896
# 166^2 = 27556
# 168^2 = 28224
# 170^2 = 28900
# 172^2 = 29584
# 174^2 = 30276
# 176^2 = 30976
# 178^2 = 31684
# 180^2 = 32400
# 182^2 = 33124
# 184^2 = 33856
# 186^2 = 34596
# 188^2 = 35344
# 190^2 = 36100
# 192^2 = 36864
# 194^2 = 37636
# 196^2 = 38416
# 198^2 = 39204
# 200^2 = 40000

# %%
#SQUARE OF ODD NUMBERS
for i in range(100,201):
    if i%2!=0:
        print(f"{i}^2 = {i*i}")
# Out:
# 101^2 = 10201
# 103^2 = 10609
# 105^2 = 11025
# 107^2 = 11449
# 109^2 = 11881
# 111^2 = 12321
# 113^2 = 12769
# 115^2 = 13225
# 117^2 = 13689
# 119^2 = 14161
# 121^2 = 14641
# 123^2 = 15129
# 125^2 = 15625
# 127^2 = 16129
# 129^2 = 16641
# 131^2 = 17161
# 133^2 = 17689
# 135^2 = 18225
# 137^2 = 18769
# 139^2 = 19321
# 141^2 = 19881
# 143^2 = 20449
# 145^2 = 21025
# 147^2 = 21609
# 149^2 = 22201
# 151^2 = 22801
# 153^2 = 23409
# 155^2 = 24025
# 157^2 = 24649
# 159^2 = 25281
# 161^2 = 25921
# 163^2 = 26569
# 165^2 = 27225
# 167^2 = 27889
# 169^2 = 28561
# 171^2 = 29241
# 173^2 = 29929
# 175^2 = 30625
# 177^2 = 31329
# 179^2 = 32041
# 181^2 = 32761
# 183^2 = 33489
# 185^2 = 34225
# 187^2 = 34969
# 189^2 = 35721
# 191^2 = 36481
# 193^2 = 37249
# 195^2 = 38025
# 197^2 = 38809
# 199^2 = 39601

# %% [markdown]
# # Exercise-3 (Hospital Billing System)

# %% [markdown]
# A hospital charges its patients based on the following:
# •	Room charges per day: ₹2,000
# •	Doctor consultation fee (flat): ₹1,500
# •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
# •	Medicine charges: Total cost of medicines provided
# •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# •	Stayed for 4 days
# •	Had 3 lab tests
# •	Had medicine charges of ₹2,400

# %%
room_charge_per_day = 2000 
doctor_fee = 1500
lab_test_charge = 300 
no_of_days_stayed = 4
room_charges = no_of_days_stayed * room_charge_per_day
no_of_lab_tests = 3
lab_charges = no_of_lab_tests * lab_test_charge
medicine_charges = 2400
total_amount= room_charges +doctor_fee + lab_charges + medicine_charges
print("Total Amount:",total_amount)
if total_amount>10000:
    Discount = (total_amount) * 10/100
    final_bill = total_amount - Discount
print("After 10% Discount:",final_bill)
# Out:
# Total Amount: 12800
# After 10% Discount: 11520.0
